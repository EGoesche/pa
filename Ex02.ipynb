# %%
import scipy.misc
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt

# %%
face = scipy.misc.face(gray=True)
plt.imshow(face)
plt.show()

# %%
gaussian_face = gaussian_filter(face, 3)
plt.imshow(gaussian_face)
plt.show()
